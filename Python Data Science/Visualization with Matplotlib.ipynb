# %%
#import package
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
#set style
plt.style.use('classic')

# %%
# %matplotlib inline
x = np.linspace(0,10,100)
plt.plot(x,np.sin(x),'-')
plt.plot(x,np.cos(x),'--')

# %%
#save figure
# fig.savefig('my_figure.png')

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x));

# %% [markdown]
# ## 1. Simple Line

# %%
plt.style.use('seaborn-whitegrid')

# %%
#start by creating a figure and their axes
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0,10,1000)
ax.plot(x,np.sin(x));

# %%
#single figure with multiple lines
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x));

# %%
#color,linestyle
plt.plot(x,np.sin(x),color='blue',linestyle='dashed')
plt.plot(x,x+4,linestyle=':');

# %%
#axes limits
plt.plot(x,np.sin(x))
plt.xlim(-1,11)
plt.ylim(-1.5,1.5);

# %%
#reverse x-axes
plt.plot(x,np.sin(x))
plt.xlim(10,0);

# %%
plt.plot(x,np.sin(x))
plt.axis('tight');

# %%
#labeling
plt.plot(x,np.sin(x))
plt.title('A sin Curve');
plt.xlabel("x");
plt.ylabel("sin(x)");

# %%
#legend
plt.plot(x,np.sin(x),'-g',label='sin(x)')
plt.plot(x,np.cos(x),':b',label='cos(X)')
plt.axis('equal');

plt.legend();

# %%
# use them all in one set
ax = plt.axes()
ax.plot(x,np.sin(x))
ax.set(xlim=(0,10),ylim=(-2,2),
      xlabel='x',ylabel='sin(x)',
      title='A Simple Plot');

# %% [markdown]
# # 2. Scatter plot

# %%
plt.style.use("seaborn-whitegrid")

# %%
#scatter plot with plt.plot
x = np.linspace(0,10,30)
y=np.sin(x)
plt.plot(x,y,'o',color='black');

# %%
#points along with a line
plt.plot(x,y,'-ok');

# %%
#more parameters
plt.plot(x,y,'-p',color='pink',markersize=15,linewidth=4,markerfacecolor='white',markeredgecolor='gray',markeredgewidth=2)
plt.ylim(-1.2,1.2);

# %%
#scatter plot with plt.scatter
plt.scatter(x,y,marker='o');

# %%
#charateristics of individual points mapped to data: multidimentional data visualization
rng=np.random.RandomState(0)
x=rng.randn(100)
y=rng.randn(100)
colors=rng.rand(100)
sizes=1000*rng.rand(100)

plt.scatter(x,y,c=colors,s=sizes,alpha=0.3,cmap="viridis")
plt.colorbar();

# %%
#iris data
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

# %%
plt.scatter(features[0],features[1],alpha=0.2,
           s=100*features[3],c=iris.target,cmap='viridis')
plt.xlabel(iris.feature_names[0])
plt.ylabel(iris.feature_names[1]);

# %%
#plt.plot is faster than plot.scatter

# %% [markdown]
# # Visualizing errors

# %%
#errorbar
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)

plt.errorbar(x,y,yerr=dy,fmt=".k");

# %%
#good settings
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
             ecolor='lightgray', elinewidth=3, capsize=0);

# %%
#contineous error visulization
plt.plot(x, y, 'or')
plt.plot(x, y, '-', color='gray')
plt.fill_between(x, y - dy, y + dy,
                 color='gray', alpha=0.2);

# %% [markdown]
# # Density and Contour plots

# %%
#visualizing three dimentional function
def f(x,y):
    return np.sin(x) **10 +np.cos(10+y*x)*np.cos(x)

x= np.linspace(0,5,50)
y=np.linspace(0,5,40)
X,Y = np.meshgrid(x,y)
Z=f(X,Y)

# %%
#line only contour plot
plt.contour(X,Y,Z);

# %%
#colormap
plt.contour(X,Y,Z,20,cmap="RdGy");

# %%
#filled contour plot
plt.contourf(X,Y,Z,20,cmap="RdGy")
plt.colorbar();

# %%
#grid gata as an image
plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image');

# %%
#combine contour plots and image plots
contours = plt.contour(X, Y, Z, 3, colors='black')
plt.clabel(contours, inline=True, fontsize=8)

plt.imshow(Z, extent=[0, 5, 0, 5], origin='lower',
           cmap='RdGy', alpha=0.5)
plt.colorbar();

# %% [markdown]
# # Histogram

# %%
data=np.random.randn(1000)

# %%
#histogram
plt.style.use('seaborn-white')
plt.hist(data);

# %%
#set bins and color
plt.hist(data,bins=30,alpha=0.5,histtype='stepfilled',color='steelblue',edgecolor='none');

# %%
#comparing histogram of several distributions

#1.data
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

# %%
#2.set kwargs
kwargs = dict(histtype='stepfilled',alpha=0.3,bins=40,edgecolor='black')

# %%
#3. histogram
plt.hist(x1,**kwargs)
plt.hist(x2,**kwargs)
plt.hist(x3,**kwargs);

# %%
#counts but not show
count, bin_edges = np.histogram(data,bins=5)
print(count)
print(bin_edges);
# Out:
# [ 39 244 435 249  33]
# [-2.98959898 -1.79874487 -0.60789077  0.58296333  1.77381744  2.96467154]

# %% [markdown]
# _____________________________________________________

# %%
#multivariate Gaussian distribution data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 10000).T

# %%
#two-dimentional histogram

plt.hist2d(x,y,bins=30,cmap='Blues')
cb = plt.colorbar()
cb.set_label('counts in bin');

# %%
#counts but not display
counts, xegdes, yedges = np.histogram2d(x,y,bins=30)
#print(counts);

# %%
#higher than two dimentions ----np.histogramdd

# %%
#use hexagon instead of squares in 2 dimentional figure

plt.hexbin(x,y,gridsize=30,cmap='Blues');
cb = plt.colorbar();
cb.set_label('count in bins')

# %%
#Kernel density estimation - KDE(scipy.stats package)

# %% [markdown]
# ## Plots legends

# %%
#set display style
plt.style.use('classic')

# %%
#plot with legend
x = np.linspace(0, 10, 1000)
fig, ax = plt.subplots()
ax.plot(x, np.sin(x), '-b', label='Sine')
ax.plot(x, np.cos(x), '--r', label='Cosine')
ax.axis('equal')
leg = ax.legend();

# %%
#customize legend - specify location and turn off the frame
ax.legend(loc='upper left',frameon=False)
fig

# %%
#customize legene location
ax.legend(loc='lower center',ncol=2,frameon=False)
fig

# %%
#customize legend frame
ax.legend(fancybox = True, framealpha=1,shadow=True,borderpad=1)
fig

# %%
#legend for size of points

# %%
#Multiple legend

fig, ax = plt.subplots()

lines = []
styles = ['-', '--', '-.', ':']
x = np.linspace(0, 10, 1000)

for i in range(4):
    lines += ax.plot(x, np.sin(x - i * np.pi / 2),
                     styles[i], color='black')
ax.axis('equal')

# specify the lines and labels of the first legend
ax.legend(lines[:2], ['line A', 'line B'],
          loc='upper right', frameon=False)

# Create the second legend and add the artist manually.
from matplotlib.legend import Legend
leg = Legend(ax, lines[2:], ['line C', 'line D'],
             loc='lower right', frameon=False)
ax.add_artist(leg);

# %% [markdown]
# ## Colorbars

# %%
plt.style.use('classic')

# %%
#simplest colorbar
x = np.linspace(0, 10, 1000)
I = np.sin(x) * np.cos(x[:, np.newaxis])

plt.imshow(I)
plt.colorbar();

# %%
#customizing colorbar
plt.imshow(I,cmap="gray");

# %%
#discrete colorbar
plt.imshow(I, cmap=plt.cm.get_cmap('Blues', 6))
plt.colorbar()
plt.clim(-1, 1);

# %% [markdown]
# ## Multiple subplot

# %%
plt.style.use('seaborn-white');

# %%
#1. subplot by hand:plt.axes
ax1 = plt.axes()  # standard axes
ax2 = plt.axes([0.65, 0.65, 0.2, 0.2])

# %%
fig = plt.figure()
ax1 = fig.add_axes([0.1, 0.5, 0.8, 0.4],
                   xticklabels=[], ylim=(-1.2, 1.2))
ax2 = fig.add_axes([0.1, 0.1, 0.8, 0.4],
                   ylim=(-1.2, 1.2))

x = np.linspace(0,10)
ax1.plot(np.sin(x))
ax2.plot(np.cos(x));

# %%
#2. Simple Grids of subplot
for i in range(1, 7):
    plt.subplot(2, 3, i)
    plt.text(0.5, 0.5, str((2, 3, i)),
             fontsize=18, ha='center');

# %%
#adjusting subplot spacing
fig = plt.figure()
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(1, 7):
    ax = fig.add_subplot(2, 3, i)
    ax.text(0.5, 0.5, str((2, 3, i)),
           fontsize=18, ha='center')

# %%
#3. The whole grid in one go : plt.subplots, most efficient
fig, ax = plt.subplots(2,3,sharex ='col',sharey='row')

# %%
for i in range(2):
    for j in range(3):
        ax[i,j].text(0.5,0.5,str((i,j)),fontsize=18,ha='center')
fig

# %%
#4. more complicated arrangement: plt.GridSpec
grid = plt.GridSpec(2, 3, wspace=0.4, hspace=0.3)

# %%
plt.subplot(grid[0, 0])
plt.subplot(grid[0, 1:])
plt.subplot(grid[1, :2])
plt.subplot(grid[1, 2]);

# %%
# an example
# Create some normally distributed data
mean = [0, 0]
cov = [[1, 1], [1, 2]]
x, y = np.random.multivariate_normal(mean, cov, 3000).T

# %%
# Set up the axes with gridspec
fig = plt.figure(figsize=(6, 6))
grid = plt.GridSpec(4, 4, hspace=0.2, wspace=0.2)
main_ax = fig.add_subplot(grid[:-1, 1:])
y_hist = fig.add_subplot(grid[:-1, 0], xticklabels=[], sharey=main_ax)
x_hist = fig.add_subplot(grid[-1, 1:], yticklabels=[], sharex=main_ax)

# scatter points on the main axes
main_ax.plot(x, y, 'ok', markersize=3, alpha=0.2)

# histogram on the attached axes
x_hist.hist(x, 40, histtype='stepfilled',
            orientation='vertical', color='gray')
x_hist.invert_yaxis()

y_hist.hist(y, 40, histtype='stepfilled',
            orientation='horizontal', color='gray')
y_hist.invert_xaxis()

# %% [markdown]
# ## text and annotation

# %%
#transform and text position
fig, ax = plt.subplots(facecolor='lightgray')
ax.axis([0, 10, 0, 10])

# transform=ax.transData is the default, but we'll specify it anyway
ax.text(1, 5, ". Data: (1, 5)", transform=ax.transData)
ax.text(0.5, 0.1, ". Axes: (0.5, 0.1)", transform=ax.transAxes)
ax.text(0.2, 0.2, ". Figure: (0.2, 0.2)", transform=fig.transFigure);

# %%
ax.set_xlim(0, 2)
ax.set_ylim(-6, 6)
fig

# %%
#arrows and annotation
fig, ax = plt.subplots()

x = np.linspace(0, 20, 1000)
ax.plot(x, np.cos(x))
ax.axis('equal')

ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))
# Out:
# Text(10,4,'local maximum')

# %%
fig, ax = plt.subplots()
ax.plot(x, np.cos(x))
ax.axis('equal')
#arrow is controled by arrowprops
ax.annotate('local maximum', xy=(6.28, 1), xytext=(10, 4),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.annotate('local minimum', xy=(5 * np.pi, -1), xytext=(2, -6),
            arrowprops=dict(arrowstyle="->",
                            connectionstyle="angle3,angleA=0,angleB=-90"));

# %% [markdown]
# ## other customization: Ticks, configuration and stylesheets

# %% [markdown]
# # Three dimentional plot
